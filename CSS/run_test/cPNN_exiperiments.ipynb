# %%
from google.colab import drive
drive.mount('/content/drive')
# going to the repository of this note book
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# CSS   datasets	models	     push_to_git.ipynb	requirements.txt  run_test
# data  lab	performance  README.md		results		  Untitled0.ipynb

# %%
# IMPORT
import os
from models.cpnn import *
from models.cpnn_others import cPNNExp
from models.cpnn_seq import cPNNSeq
from models.cgru import cGRULinear
from models.clstm import *
import numpy as np
import pandas as pd
import pickle
import argparse

# %% [markdown]
# ##This part is related to run CPNN with gru layers

# %%
# EDITABLE PARAMETERS
dataset = "sine_rw10_mode5_extended_16-16_1234"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
rembember_initial_states = False
suffix = ""

if freeze_inputs_weights:
    suffix += "_exp"
if combination:
    suffix = "_combination" + suffix
if suffix != "" and suffix[0:1] != "_":
    suffix = "_" + suffix
parser = argparse.ArgumentParser()
parser.add_argument(
    "--model",
    type=str,
    default="cpnn",
    help="Model to use: {'cpnn', 'single': cLSTM, 'multiple': mcLSTM}",
)
parser.add_argument(
    "--model_class",
    type=str,
    default="cgru",
    help="Base learner to use: {'clstm', 'cgru'}",
)
args,_ = parser.parse_known_args()

if args.model_class == "clstm":
    model_class = cLSTMLinear
else:
    model_class = cGRULinear
if hidden_size is None:
    if args.model_class == "clstm":
        hidden_size = 50
    else:
        hidden_size = 128
device = torch.device("cpu")
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
perf_test = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_train = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_anytime = {"accuracy": [], "kappa": [], "kappa_temporal": []}
seq_str = "_seq" if loss_on_seq else ""

path = os.path.join(
    "performance",
    f"{dataset}/{args.model}_{args.model_class}{seq_str}{suffix}_{hidden_size}hs",
)
if not os.path.isdir(path):
    os.makedirs(path)

path_anytime = path + "_anytime"
if not os.path.isdir(path_anytime):
    os.makedirs(path_anytime)

# UTILS
print(model_class)
def create_cpnn():
    if not loss_on_seq:
        if not freeze_inputs_weights:
            return cPNN(column_class=model_class, device=device, seq_len=seq_len, train_verbose=False,
                        combination=combination, input_size=len(df.columns) - 2, hidden_size=hidden_size, output_size=2,
                        batch_size=batch_size)
        else:
            return cPNNExp(
                column_class=model_class,
                input_size=len(df.columns) - 2,
                hidden_size=hidden_size,
                output_size=2,
                batch_size=batch_size,
                device=device,
                seq_len=seq_len,
                train_verbose=False,
                combination=combination,
                remember_initial_states=rembember_initial_states,
            )
    return cPNNSeq(
        column_class=model_class,
        input_size=len(df.columns) - 2,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
        device=device,
        seq_len=seq_len,
    )


# MAIN
if __name__ == "__main__":
    if args.model == "cpnn" and write_weights:
        try:
            df_test = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}_test.csv"))
        except:
            pass
    models = []
    params = []
    inputs = []
    hiddens = []
    acc=[]
    kappa=[]

    print(dataset)
    for i in range(1, iterations + 1):
        models.append([])
        params.append([])
        inputs.append([])
        hiddens.append([])

        for k in perf_test:
            perf_test[k].append([])
        for k in perf_train:
            perf_train[k].append([])
        for k in perf_anytime:
            perf_anytime[k].append([])
        models[-1].append(create_cpnn())
        print(type(models[-1][-1].columns.columns[0]).__name__)
        print(f"{i}/{iterations} iteration of {args.model}")
        for task in range(1, df["task"].max() + 1):
            acc.append([])
            kappa.append([])
            params[-1].append([])
            inputs[-1].append([])
            hiddens[-1].append([])
            print("TASK:", task)
            if task > 1:
                if args.model == "cpnn":
                    models[-1][-1].add_new_column()
                elif args.model == "multiple":
                    models[-1].append(create_cpnn())
                elif args.model == "single":
                    models[-1].append(pickle.loads(pickle.dumps(models[-1][-1])))
            df_task = df[df["task"] == task]
            df_task = df_task.drop(columns="task")

            if pretraining_samples > 0:
                df_pre = df_task.iloc[:pretraining_samples, 0:]
                df_task = df_task.iloc[pretraining_samples:, 0:]
                perf_pretraining = models[-1][-1].pretraining(
                    df_pre.iloc[0:, :-1].values.astype(np.float32),
                    list(df_pre.iloc[0:, -1]),
                    pretraining_epochs,
                )
                with open(
                    os.path.join(path, "pretraining.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(perf_pretraining, f)

            for k in perf_test:
                perf_test[k][-1].append([])
            for k in perf_train:
                perf_train[k][-1].append([])
            for k in perf_anytime:
                perf_anytime[k][-1].append([])
            if len(df_task) % batch_size == 0:
                n_batches = int(len(df_task) / batch_size)
            else:
                n_batches = int(len(df_task) / batch_size) + 1
            for i in range(0, len(df_task), batch_size):
                x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
                y = list(df_task.iloc[i : i + batch_size, -1])
                print(int(i / batch_size) + 1, "/", n_batches, " batch", end="\r")
                if len(y) >= seq_len:
                    batch_perf_test, batch_perf_anytime, batch_perf_train = models[-1][-1].test_then_train(
                        x, y
                    )
                    acc[-1].append([batch_perf_test['accuracy']])
                    kappa[-1].append([batch_perf_test['kappa']])
                    for k in batch_perf_test:
                        perf_test[k][-1][-1].append(batch_perf_test[k])
                    for k in batch_perf_anytime:
                        perf_anytime[k][-1][-1].append(batch_perf_anytime[k])
                    for k in batch_perf_train:
                        perf_train[k][-1][-1].append(batch_perf_train[k])
                    if args.model == "cpnn" and write_weights:
                        try:
                            df_test_task = df_test[df_test["task"] == task].drop(
                                columns="task"
                            )
                            x_test = df_test_task.iloc[0:500, 0:-1].values.astype(
                                np.float32
                            )
                            inputs[-1][-1].append(
                                models[-1][-1]
                                .columns._convert_to_tensor_dataset(x_test)
                                .detach()
                                .numpy()
                            )
                            hiddens[-1][-1].append(models[-1][-1].get_hidden(x_test))
                        except:
                            pass
                        params[-1][-1].append(
                            pickle.loads(
                                pickle.dumps(
                                    models[-1][-1]
                                    .columns.columns[-1]
                                    .lstm.weight_ih_l0.data.detach()
                                    .numpy()
                                )
                            )
                        )
            print()
            print(
                f"Accuracy media sul task {task}: {np.mean(perf_test['accuracy'][-1][-1])}"
            )
            print()

            with open(
                os.path.join(path, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_test, f)

            with open(
                os.path.join(path_anytime, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_anytime, f)

            with open(
                os.path.join(path, "train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_train, f)
            with open(os.path.join(path, "models.pkl"), "wb") as f:
                pickle.dump(models, f)

            if args.model == "cpnn" and write_weights:
                with open(
                    os.path.join(path, "cpnn_params.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(params, f)

                with open(
                    os.path.join(path, "inputs.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(inputs, f)

                with open(
                    os.path.join(path, "hiddens.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(hiddens, f)
        print()
# Out:
# <class 'models.cgru.cGRULinear'>
# sine_rw10_mode5_extended_16-16_1234
# cGRULinear
# 1/1 iteration of cpnn
# TASK: 1
#
# Accuracy media sul task 1: 0.9086437020460358
#
# TASK: 2
#
# Accuracy media sul task 2: 0.837380115089514
#
# TASK: 3
#
# Accuracy media sul task 3: 0.9426550511508951
#
# TASK: 4
#
# Accuracy media sul task 4: 0.8814737851662404

# %%
np.mean(kappa, axis=1)
# Out:
# array([[0.81959491],
#        [0.64272878],
#        [0.90241561],
#        [0.74828695]])

# %%
pd.DataFrame(acc).to_csv('results/acc-cpnn-16_16-1234.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-cpnn-16_16-1234.csv', index=False)

# %%
# EDITABLE PARAMETERS
dataset = "sine_rw10_mode5_extended_16-16_1432"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
rembember_initial_states = False
suffix = ""

if freeze_inputs_weights:
    suffix += "_exp"
if combination:
    suffix = "_combination" + suffix
if suffix != "" and suffix[0:1] != "_":
    suffix = "_" + suffix
parser = argparse.ArgumentParser()
parser.add_argument(
    "--model",
    type=str,
    default="cpnn",
    help="Model to use: {'cpnn', 'single': cLSTM, 'multiple': mcLSTM}",
)
parser.add_argument(
    "--model_class",
    type=str,
    default="cgru",
    help="Base learner to use: {'clstm', 'cgru'}",
)
args,_ = parser.parse_known_args()

if args.model_class == "clstm":
    model_class = cLSTMLinear
else:
    model_class = cGRULinear
if hidden_size is None:
    if args.model_class == "clstm":
        hidden_size = 50
    else:
        hidden_size = 128
device = torch.device("cpu")
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
perf_test = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_train = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_anytime = {"accuracy": [], "kappa": [], "kappa_temporal": []}
seq_str = "_seq" if loss_on_seq else ""

path = os.path.join(
    "performance",
    f"{dataset}/{args.model}_{args.model_class}{seq_str}{suffix}_{hidden_size}hs",
)
if not os.path.isdir(path):
    os.makedirs(path)

path_anytime = path + "_anytime"
if not os.path.isdir(path_anytime):
    os.makedirs(path_anytime)

# UTILS
print(model_class)
def create_cpnn():
    if not loss_on_seq:
        if not freeze_inputs_weights:
            return cPNN(column_class=model_class, device=device, seq_len=seq_len, train_verbose=False,
                        combination=combination, input_size=len(df.columns) - 2, hidden_size=hidden_size, output_size=2,
                        batch_size=batch_size)
        else:
            return cPNNExp(
                column_class=model_class,
                input_size=len(df.columns) - 2,
                hidden_size=hidden_size,
                output_size=2,
                batch_size=batch_size,
                device=device,
                seq_len=seq_len,
                train_verbose=False,
                combination=combination,
                remember_initial_states=rembember_initial_states,
            )
    return cPNNSeq(
        column_class=model_class,
        input_size=len(df.columns) - 2,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
        device=device,
        seq_len=seq_len,
    )


# MAIN
if __name__ == "__main__":
    if args.model == "cpnn" and write_weights:
        try:
            df_test = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}_test.csv"))
        except:
            pass
    models = []
    params = []
    inputs = []
    hiddens = []
    acc=[]
    kappa=[]

    print(dataset)
    for i in range(1, iterations + 1):
        models.append([])
        params.append([])
        inputs.append([])
        hiddens.append([])

        for k in perf_test:
            perf_test[k].append([])
        for k in perf_train:
            perf_train[k].append([])
        for k in perf_anytime:
            perf_anytime[k].append([])
        models[-1].append(create_cpnn())
        print(type(models[-1][-1].columns.columns[0]).__name__)
        print(f"{i}/{iterations} iteration of {args.model}")
        for task in range(1, df["task"].max() + 1):
            acc.append([])
            kappa.append([])
            params[-1].append([])
            inputs[-1].append([])
            hiddens[-1].append([])
            print("TASK:", task)
            if task > 1:
                if args.model == "cpnn":
                    models[-1][-1].add_new_column()
                elif args.model == "multiple":
                    models[-1].append(create_cpnn())
                elif args.model == "single":
                    models[-1].append(pickle.loads(pickle.dumps(models[-1][-1])))
            df_task = df[df["task"] == task]
            df_task = df_task.drop(columns="task")

            if pretraining_samples > 0:
                df_pre = df_task.iloc[:pretraining_samples, 0:]
                df_task = df_task.iloc[pretraining_samples:, 0:]
                perf_pretraining = models[-1][-1].pretraining(
                    df_pre.iloc[0:, :-1].values.astype(np.float32),
                    list(df_pre.iloc[0:, -1]),
                    pretraining_epochs,
                )
                with open(
                    os.path.join(path, "pretraining.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(perf_pretraining, f)

            for k in perf_test:
                perf_test[k][-1].append([])
            for k in perf_train:
                perf_train[k][-1].append([])
            for k in perf_anytime:
                perf_anytime[k][-1].append([])
            if len(df_task) % batch_size == 0:
                n_batches = int(len(df_task) / batch_size)
            else:
                n_batches = int(len(df_task) / batch_size) + 1
            for i in range(0, len(df_task), batch_size):
                x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
                y = list(df_task.iloc[i : i + batch_size, -1])
                print(int(i / batch_size) + 1, "/", n_batches, " batch", end="\r")
                if len(y) >= seq_len:
                    batch_perf_test, batch_perf_anytime, batch_perf_train = models[-1][-1].test_then_train(
                        x, y
                    )
                    acc[-1].append([batch_perf_test['accuracy']])
                    kappa[-1].append([batch_perf_test['kappa']])
                    for k in batch_perf_test:
                        perf_test[k][-1][-1].append(batch_perf_test[k])
                    for k in batch_perf_anytime:
                        perf_anytime[k][-1][-1].append(batch_perf_anytime[k])
                    for k in batch_perf_train:
                        perf_train[k][-1][-1].append(batch_perf_train[k])
                    if args.model == "cpnn" and write_weights:
                        try:
                            df_test_task = df_test[df_test["task"] == task].drop(
                                columns="task"
                            )
                            x_test = df_test_task.iloc[0:500, 0:-1].values.astype(
                                np.float32
                            )
                            inputs[-1][-1].append(
                                models[-1][-1]
                                .columns._convert_to_tensor_dataset(x_test)
                                .detach()
                                .numpy()
                            )
                            hiddens[-1][-1].append(models[-1][-1].get_hidden(x_test))
                        except:
                            pass
                        params[-1][-1].append(
                            pickle.loads(
                                pickle.dumps(
                                    models[-1][-1]
                                    .columns.columns[-1]
                                    .lstm.weight_ih_l0.data.detach()
                                    .numpy()
                                )
                            )
                        )
            print()
            print(
                f"Accuracy media sul task {task}: {np.mean(perf_test['accuracy'][-1][-1])}"
            )
            print()

            with open(
                os.path.join(path, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_test, f)

            with open(
                os.path.join(path_anytime, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_anytime, f)

            with open(
                os.path.join(path, "train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_train, f)
            with open(os.path.join(path, "models.pkl"), "wb") as f:
                pickle.dump(models, f)

            if args.model == "cpnn" and write_weights:
                with open(
                    os.path.join(path, "cpnn_params.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(params, f)

                with open(
                    os.path.join(path, "inputs.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(inputs, f)

                with open(
                    os.path.join(path, "hiddens.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(hiddens, f)
        print()
# Out:
# <class 'models.cgru.cGRULinear'>
# sine_rw10_mode5_extended_16-16_1432
# cGRULinear
# 1/1 iteration of cpnn
# TASK: 1
#
# Accuracy media sul task 1: 0.9152933184143223
#
# TASK: 2
#
# Accuracy media sul task 2: 0.8282169117647058
#
# TASK: 3
#
# Accuracy media sul task 3: 0.9507872442455243
#
# TASK: 4
#
# Accuracy media sul task 4: 0.8776094948849105

# %%
pd.DataFrame(acc).to_csv('results/acc-cpnn-16_16-1432.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-cpnn-16_16-1432.csv', index=False)

# %%
# EDITABLE PARAMETERS
dataset = "sine_rw10_mode5_extended_16-16_2341"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
rembember_initial_states = False
suffix = ""

if freeze_inputs_weights:
    suffix += "_exp"
if combination:
    suffix = "_combination" + suffix
if suffix != "" and suffix[0:1] != "_":
    suffix = "_" + suffix
parser = argparse.ArgumentParser()
parser.add_argument(
    "--model",
    type=str,
    default="cpnn",
    help="Model to use: {'cpnn', 'single': cLSTM, 'multiple': mcLSTM}",
)
parser.add_argument(
    "--model_class",
    type=str,
    default="cgru",
    help="Base learner to use: {'clstm', 'cgru'}",
)
args,_ = parser.parse_known_args()

if args.model_class == "clstm":
    model_class = cLSTMLinear
else:
    model_class = cGRULinear
if hidden_size is None:
    if args.model_class == "clstm":
        hidden_size = 50
    else:
        hidden_size = 128
device = torch.device("cpu")
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
perf_test = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_train = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_anytime = {"accuracy": [], "kappa": [], "kappa_temporal": []}
seq_str = "_seq" if loss_on_seq else ""

path = os.path.join(
    "performance",
    f"{dataset}/{args.model}_{args.model_class}{seq_str}{suffix}_{hidden_size}hs",
)
if not os.path.isdir(path):
    os.makedirs(path)

path_anytime = path + "_anytime"
if not os.path.isdir(path_anytime):
    os.makedirs(path_anytime)

# UTILS
print(model_class)
def create_cpnn():
    if not loss_on_seq:
        if not freeze_inputs_weights:
            return cPNN(column_class=model_class, device=device, seq_len=seq_len, train_verbose=False,
                        combination=combination, input_size=len(df.columns) - 2, hidden_size=hidden_size, output_size=2,
                        batch_size=batch_size)
        else:
            return cPNNExp(
                column_class=model_class,
                input_size=len(df.columns) - 2,
                hidden_size=hidden_size,
                output_size=2,
                batch_size=batch_size,
                device=device,
                seq_len=seq_len,
                train_verbose=False,
                combination=combination,
                remember_initial_states=rembember_initial_states,
            )
    return cPNNSeq(
        column_class=model_class,
        input_size=len(df.columns) - 2,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
        device=device,
        seq_len=seq_len,
    )


# MAIN
if __name__ == "__main__":
    if args.model == "cpnn" and write_weights:
        try:
            df_test = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}_test.csv"))
        except:
            pass
    models = []
    params = []
    inputs = []
    hiddens = []
    acc=[]
    kappa=[]

    print(dataset)
    for i in range(1, iterations + 1):
        models.append([])
        params.append([])
        inputs.append([])
        hiddens.append([])

        for k in perf_test:
            perf_test[k].append([])
        for k in perf_train:
            perf_train[k].append([])
        for k in perf_anytime:
            perf_anytime[k].append([])
        models[-1].append(create_cpnn())
        print(type(models[-1][-1].columns.columns[0]).__name__)
        print(f"{i}/{iterations} iteration of {args.model}")
        for task in range(1, df["task"].max() + 1):
            acc.append([])
            kappa.append([])
            params[-1].append([])
            inputs[-1].append([])
            hiddens[-1].append([])
            print("TASK:", task)
            if task > 1:
                if args.model == "cpnn":
                    models[-1][-1].add_new_column()
                elif args.model == "multiple":
                    models[-1].append(create_cpnn())
                elif args.model == "single":
                    models[-1].append(pickle.loads(pickle.dumps(models[-1][-1])))
            df_task = df[df["task"] == task]
            df_task = df_task.drop(columns="task")

            if pretraining_samples > 0:
                df_pre = df_task.iloc[:pretraining_samples, 0:]
                df_task = df_task.iloc[pretraining_samples:, 0:]
                perf_pretraining = models[-1][-1].pretraining(
                    df_pre.iloc[0:, :-1].values.astype(np.float32),
                    list(df_pre.iloc[0:, -1]),
                    pretraining_epochs,
                )
                with open(
                    os.path.join(path, "pretraining.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(perf_pretraining, f)

            for k in perf_test:
                perf_test[k][-1].append([])
            for k in perf_train:
                perf_train[k][-1].append([])
            for k in perf_anytime:
                perf_anytime[k][-1].append([])
            if len(df_task) % batch_size == 0:
                n_batches = int(len(df_task) / batch_size)
            else:
                n_batches = int(len(df_task) / batch_size) + 1
            for i in range(0, len(df_task), batch_size):
                x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
                y = list(df_task.iloc[i : i + batch_size, -1])
                print(int(i / batch_size) + 1, "/", n_batches, " batch", end="\r")
                if len(y) >= seq_len:
                    batch_perf_test, batch_perf_anytime, batch_perf_train = models[-1][-1].test_then_train(
                        x, y
                    )
                    acc[-1].append([batch_perf_test['accuracy']])
                    kappa[-1].append([batch_perf_test['kappa']])
                    for k in batch_perf_test:
                        perf_test[k][-1][-1].append(batch_perf_test[k])
                    for k in batch_perf_anytime:
                        perf_anytime[k][-1][-1].append(batch_perf_anytime[k])
                    for k in batch_perf_train:
                        perf_train[k][-1][-1].append(batch_perf_train[k])
                    if args.model == "cpnn" and write_weights:
                        try:
                            df_test_task = df_test[df_test["task"] == task].drop(
                                columns="task"
                            )
                            x_test = df_test_task.iloc[0:500, 0:-1].values.astype(
                                np.float32
                            )
                            inputs[-1][-1].append(
                                models[-1][-1]
                                .columns._convert_to_tensor_dataset(x_test)
                                .detach()
                                .numpy()
                            )
                            hiddens[-1][-1].append(models[-1][-1].get_hidden(x_test))
                        except:
                            pass
                        params[-1][-1].append(
                            pickle.loads(
                                pickle.dumps(
                                    models[-1][-1]
                                    .columns.columns[-1]
                                    .lstm.weight_ih_l0.data.detach()
                                    .numpy()
                                )
                            )
                        )
            print()
            print(
                f"Accuracy media sul task {task}: {np.mean(perf_test['accuracy'][-1][-1])}"
            )
            print()

            with open(
                os.path.join(path, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_test, f)

            with open(
                os.path.join(path_anytime, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_anytime, f)

            with open(
                os.path.join(path, "train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_train, f)
            with open(os.path.join(path, "models.pkl"), "wb") as f:
                pickle.dump(models, f)

            if args.model == "cpnn" and write_weights:
                with open(
                    os.path.join(path, "cpnn_params.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(params, f)

                with open(
                    os.path.join(path, "inputs.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(inputs, f)

                with open(
                    os.path.join(path, "hiddens.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(hiddens, f)
        print()
# Out:
# <class 'models.cgru.cGRULinear'>
# sine_rw10_mode5_extended_16-16_2341
# cGRULinear
# 1/1 iteration of cpnn
# TASK: 1
#
# Accuracy media sul task 1: 0.8098984974424553
#
# TASK: 2
#
# Accuracy media sul task 2: 0.8889426150895141
#
# TASK: 3
#
# Accuracy media sul task 3: 0.8734454923273657
#
# TASK: 4
#
# Accuracy media sul task 4: 0.9525095907928388

# %%
pd.DataFrame(acc).to_csv('results/acc-cpnn-16_16-2341.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-cpnn-16_16-2341.csv', index=False)

# %%
# EDITABLE PARAMETERS
dataset = "sine_rw10_mode5_extended_16-16_2143"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
rembember_initial_states = False
suffix = ""

if freeze_inputs_weights:
    suffix += "_exp"
if combination:
    suffix = "_combination" + suffix
if suffix != "" and suffix[0:1] != "_":
    suffix = "_" + suffix
parser = argparse.ArgumentParser()
parser.add_argument(
    "--model",
    type=str,
    default="cpnn",
    help="Model to use: {'cpnn', 'single': cLSTM, 'multiple': mcLSTM}",
)
parser.add_argument(
    "--model_class",
    type=str,
    default="cgru",
    help="Base learner to use: {'clstm', 'cgru'}",
)
args,_ = parser.parse_known_args()

if args.model_class == "clstm":
    model_class = cLSTMLinear
else:
    model_class = cGRULinear
if hidden_size is None:
    if args.model_class == "clstm":
        hidden_size = 50
    else:
        hidden_size = 128
device = torch.device("cpu")
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
perf_test = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_train = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_anytime = {"accuracy": [], "kappa": [], "kappa_temporal": []}
seq_str = "_seq" if loss_on_seq else ""

path = os.path.join(
    "performance",
    f"{dataset}/{args.model}_{args.model_class}{seq_str}{suffix}_{hidden_size}hs",
)
if not os.path.isdir(path):
    os.makedirs(path)

path_anytime = path + "_anytime"
if not os.path.isdir(path_anytime):
    os.makedirs(path_anytime)

# UTILS
print(model_class)
def create_cpnn():
    if not loss_on_seq:
        if not freeze_inputs_weights:
            return cPNN(column_class=model_class, device=device, seq_len=seq_len, train_verbose=False,
                        combination=combination, input_size=len(df.columns) - 2, hidden_size=hidden_size, output_size=2,
                        batch_size=batch_size)
        else:
            return cPNNExp(
                column_class=model_class,
                input_size=len(df.columns) - 2,
                hidden_size=hidden_size,
                output_size=2,
                batch_size=batch_size,
                device=device,
                seq_len=seq_len,
                train_verbose=False,
                combination=combination,
                remember_initial_states=rembember_initial_states,
            )
    return cPNNSeq(
        column_class=model_class,
        input_size=len(df.columns) - 2,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
        device=device,
        seq_len=seq_len,
    )


# MAIN
if __name__ == "__main__":
    if args.model == "cpnn" and write_weights:
        try:
            df_test = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}_test.csv"))
        except:
            pass
    models = []
    params = []
    inputs = []
    hiddens = []
    acc=[]
    kappa=[]

    print(dataset)
    for i in range(1, iterations + 1):
        models.append([])
        params.append([])
        inputs.append([])
        hiddens.append([])

        for k in perf_test:
            perf_test[k].append([])
        for k in perf_train:
            perf_train[k].append([])
        for k in perf_anytime:
            perf_anytime[k].append([])
        models[-1].append(create_cpnn())
        print(type(models[-1][-1].columns.columns[0]).__name__)
        print(f"{i}/{iterations} iteration of {args.model}")
        for task in range(1, df["task"].max() + 1):
            acc.append([])
            kappa.append([])
            params[-1].append([])
            inputs[-1].append([])
            hiddens[-1].append([])
            print("TASK:", task)
            if task > 1:
                if args.model == "cpnn":
                    models[-1][-1].add_new_column()
                elif args.model == "multiple":
                    models[-1].append(create_cpnn())
                elif args.model == "single":
                    models[-1].append(pickle.loads(pickle.dumps(models[-1][-1])))
            df_task = df[df["task"] == task]
            df_task = df_task.drop(columns="task")

            if pretraining_samples > 0:
                df_pre = df_task.iloc[:pretraining_samples, 0:]
                df_task = df_task.iloc[pretraining_samples:, 0:]
                perf_pretraining = models[-1][-1].pretraining(
                    df_pre.iloc[0:, :-1].values.astype(np.float32),
                    list(df_pre.iloc[0:, -1]),
                    pretraining_epochs,
                )
                with open(
                    os.path.join(path, "pretraining.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(perf_pretraining, f)

            for k in perf_test:
                perf_test[k][-1].append([])
            for k in perf_train:
                perf_train[k][-1].append([])
            for k in perf_anytime:
                perf_anytime[k][-1].append([])
            if len(df_task) % batch_size == 0:
                n_batches = int(len(df_task) / batch_size)
            else:
                n_batches = int(len(df_task) / batch_size) + 1
            for i in range(0, len(df_task), batch_size):
                x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
                y = list(df_task.iloc[i : i + batch_size, -1])
                print(int(i / batch_size) + 1, "/", n_batches, " batch", end="\r")
                if len(y) >= seq_len:
                    batch_perf_test, batch_perf_anytime, batch_perf_train = models[-1][-1].test_then_train(
                        x, y
                    )
                    acc[-1].append([batch_perf_test['accuracy']])
                    kappa[-1].append([batch_perf_test['kappa']])
                    for k in batch_perf_test:
                        perf_test[k][-1][-1].append(batch_perf_test[k])
                    for k in batch_perf_anytime:
                        perf_anytime[k][-1][-1].append(batch_perf_anytime[k])
                    for k in batch_perf_train:
                        perf_train[k][-1][-1].append(batch_perf_train[k])
                    if args.model == "cpnn" and write_weights:
                        try:
                            df_test_task = df_test[df_test["task"] == task].drop(
                                columns="task"
                            )
                            x_test = df_test_task.iloc[0:500, 0:-1].values.astype(
                                np.float32
                            )
                            inputs[-1][-1].append(
                                models[-1][-1]
                                .columns._convert_to_tensor_dataset(x_test)
                                .detach()
                                .numpy()
                            )
                            hiddens[-1][-1].append(models[-1][-1].get_hidden(x_test))
                        except:
                            pass
                        params[-1][-1].append(
                            pickle.loads(
                                pickle.dumps(
                                    models[-1][-1]
                                    .columns.columns[-1]
                                    .lstm.weight_ih_l0.data.detach()
                                    .numpy()
                                )
                            )
                        )
            print()
            print(
                f"Accuracy media sul task {task}: {np.mean(perf_test['accuracy'][-1][-1])}"
            )
            print()

            with open(
                os.path.join(path, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_test, f)

            with open(
                os.path.join(path_anytime, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_anytime, f)

            with open(
                os.path.join(path, "train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_train, f)
            with open(os.path.join(path, "models.pkl"), "wb") as f:
                pickle.dump(models, f)

            if args.model == "cpnn" and write_weights:
                with open(
                    os.path.join(path, "cpnn_params.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(params, f)

                with open(
                    os.path.join(path, "inputs.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(inputs, f)

                with open(
                    os.path.join(path, "hiddens.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(hiddens, f)
        print()
# Out:
# <class 'models.cgru.cGRULinear'>
# sine_rw10_mode5_extended_16-16_2143
# cGRULinear
# 1/1 iteration of cpnn
# TASK: 1
#
# Accuracy media sul task 1: 0.8116528132992327
#
# TASK: 2
#
# Accuracy media sul task 2: 0.8892223465473147
#
# TASK: 3
#
# Accuracy media sul task 3: 0.8701326726342711
#
# TASK: 4
#
# Accuracy media sul task 4: 0.935789641943734

# %%
pd.DataFrame(acc).to_csv('results/acc-cpnn-16_16-2143.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-cpnn-16_16-2143.csv', index=False)

# %% [markdown]
# ##This is for running CPNN with gru and pretrain model based on train data

# %%
# EDITABLE PARAMETERS
dataset1 = "sine_rw10_mode5_extended_6-6_1234"
pretrain_data = pd.read_csv(os.path.join("datasets/datasets", f"{dataset1}.csv"))
pretrain_data = pretrain_data[pretrain_data["task"] == 3]
pretrain_data.loc[:, 'task'] = 0
dataset2 = "sine_rw10_mode5_extended_16-16_1234"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
rembember_initial_states = False
suffix = ""

if freeze_inputs_weights:
    suffix += "_exp"
if combination:
    suffix = "_combination" + suffix
if suffix != "" and suffix[0:1] != "_":
    suffix = "_" + suffix
parser = argparse.ArgumentParser()
parser.add_argument(
    "--model",
    type=str,
    default="cpnn",
    help="Model to use: {'cpnn', 'single': cLSTM, 'multiple': mcLSTM}",
)
parser.add_argument(
    "--model_class",
    type=str,
    default="cgru",
    help="Base learner to use: {'clstm', 'cgru'}",
)
args,_ = parser.parse_known_args()

if args.model_class == "clstm":
    model_class = cLSTMLinear
else:
    model_class = cGRULinear
if hidden_size is None:
    if args.model_class == "clstm":
        hidden_size = 50
    else:
        hidden_size = 128
device = torch.device("cpu")
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset2}.csv"))

df = pretrain_data.append(df, ignore_index=True)
perf_test = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_train = {"accuracy": [], "kappa": [], "kappa_temporal": [], "loss": []}
perf_anytime = {"accuracy": [], "kappa": [], "kappa_temporal": []}
seq_str = "_seq" if loss_on_seq else ""

path = os.path.join(
    "performance",
    f"{dataset2}/{args.model}_{args.model_class}{seq_str}{suffix}_{hidden_size}hs",
)
if not os.path.isdir(path):
    os.makedirs(path)

path_anytime = path + "_anytime"
if not os.path.isdir(path_anytime):
    os.makedirs(path_anytime)

# UTILS
print(model_class)
def create_cpnn():
    if not loss_on_seq:
        if not freeze_inputs_weights:
            return cPNN(column_class=model_class, device=device, seq_len=seq_len, train_verbose=False,
                        combination=combination, input_size=len(df.columns) - 2, hidden_size=hidden_size, output_size=2,
                        batch_size=batch_size)
        else:
            return cPNNExp(
                column_class=model_class,
                input_size=len(df.columns) - 2,
                hidden_size=hidden_size,
                output_size=2,
                batch_size=batch_size,
                device=device,
                seq_len=seq_len,
                train_verbose=False,
                combination=combination,
                remember_initial_states=rembember_initial_states,
            )
    return cPNNSeq(
        column_class=model_class,
        input_size=len(df.columns) - 2,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
        device=device,
        seq_len=seq_len,
    )


# MAIN
if __name__ == "__main__":
    if args.model == "cpnn" and write_weights:
        try:
            df_test = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}_test.csv"))
        except:
            pass
    models = []
    params = []
    inputs = []
    hiddens = []
    acc=[]
    kappa=[]

    print(dataset2)
    for i in range(1, iterations + 1):
        models.append([])
        params.append([])
        inputs.append([])
        hiddens.append([])

        for k in perf_test:
            perf_test[k].append([])
        for k in perf_train:
            perf_train[k].append([])
        for k in perf_anytime:
            perf_anytime[k].append([])
        models[-1].append(create_cpnn())
        print(type(models[-1][-1].columns.columns[0]).__name__)
        print(f"{i}/{iterations} iteration of {args.model}")
        for task in range(0, df["task"].max() + 1):
            acc.append([])
            kappa.append([])
            params[-1].append([])
            inputs[-1].append([])
            hiddens[-1].append([])
            print("TASK:", task)
            if task > 0:
                if args.model == "cpnn":
                    models[-1][-1].add_new_column()
                elif args.model == "multiple":
                    models[-1].append(create_cpnn())
                elif args.model == "single":
                    models[-1].append(pickle.loads(pickle.dumps(models[-1][-1])))
            df_task = df[df["task"] == task]
            #df_task.loc[:, 'task'] = 1
            df_task = df_task.drop(columns="task")
            if pretraining_samples > 0:
                df_pre = df_task.iloc[:pretraining_samples, 0:]
                df_task = df_task.iloc[pretraining_samples:, 0:]
                perf_pretraining = models[-1][-1].pretraining(
                    df_pre.iloc[0:, :-1].values.astype(np.float32),
                    list(df_pre.iloc[0:, -1]),
                    pretraining_epochs,
                )
                with open(
                    os.path.join(path, "pretraining.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(perf_pretraining, f)

            for k in perf_test:
                perf_test[k][-1].append([])
            for k in perf_train:
                perf_train[k][-1].append([])
            for k in perf_anytime:
                perf_anytime[k][-1].append([])
            if len(df_task) % batch_size == 0:
                n_batches = int(len(df_task) / batch_size)
            else:
                n_batches = int(len(df_task) / batch_size) + 1
            for i in range(0, len(df_task), batch_size):
                x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
                y = list(df_task.iloc[i : i + batch_size, -1])
                print(int(i / batch_size) + 1, "/", n_batches, " batch", end="\r")
                if len(y) >= seq_len:
                    batch_perf_test, batch_perf_anytime, batch_perf_train = models[-1][-1].test_then_train(
                        x, y
                    )
                    acc[-1].append([batch_perf_test['accuracy']])
                    kappa[-1].append([batch_perf_test['kappa']])
                    for k in batch_perf_test:
                        perf_test[k][-1][-1].append(batch_perf_test[k])
                    for k in batch_perf_anytime:
                        perf_anytime[k][-1][-1].append(batch_perf_anytime[k])
                    for k in batch_perf_train:
                        perf_train[k][-1][-1].append(batch_perf_train[k])
                    if args.model == "cpnn" and write_weights:
                        try:
                            df_test_task = df_test[df_test["task"] == task].drop(
                                columns="task"
                            )
                            x_test = df_test_task.iloc[0:500, 0:-1].values.astype(
                                np.float32
                            )
                            inputs[-1][-1].append(
                                models[-1][-1]
                                .columns._convert_to_tensor_dataset(x_test)
                                .detach()
                                .numpy()
                            )
                            hiddens[-1][-1].append(models[-1][-1].get_hidden(x_test))
                        except:
                            pass
                        params[-1][-1].append(
                            pickle.loads(
                                pickle.dumps(
                                    models[-1][-1]
                                    .columns.columns[-1]
                                    .lstm.weight_ih_l0.data.detach()
                                    .numpy()
                                )
                            )
                        )
            print()
            print(
                f"Accuracy media sul task {task}: {np.mean(perf_test['accuracy'][-1][-1])}"
            )
            print()

            with open(
                os.path.join(path, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_test, f)

            with open(
                os.path.join(path_anytime, "test_then_train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_anytime, f)

            with open(
                os.path.join(path, "train.pkl"),
                "wb",
            ) as f:
                pickle.dump(perf_train, f)
            with open(os.path.join(path, "models.pkl"), "wb") as f:
                pickle.dump(models, f)

            if args.model == "cpnn" and write_weights:
                with open(
                    os.path.join(path, "cpnn_params.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(params, f)

                with open(
                    os.path.join(path, "inputs.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(inputs, f)

                with open(
                    os.path.join(path, "hiddens.pkl"),
                    "wb",
                ) as f:
                    pickle.dump(hiddens, f)
        print()
# Out:
# <ipython-input-5-8723c3cc142b>:56: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = pretrain_data.append(df, ignore_index=True)
# <class 'models.cgru.cGRULinear'>
# sine_rw10_mode5_extended_16-16_1234
# cGRULinear
# 1/1 iteration of cpnn
# TASK: 0
#
# Accuracy media sul task 0: 0.9057265025575448
#
# TASK: 1
#
# Accuracy media sul task 1: 0.8606697570332481
#
# TASK: 2

# %%
pd.DataFrame(acc).to_csv('results/acc-cpnn-16_16-1234-pretrain-t3.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-cpnn-16_16-1234-pretrain-t3.csv', index=False)
