# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# going to the repository of this note book
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# CSS   datasets	models	     push_to_git.ipynb	requirements.txt  run_test
# data  lab	performance  README.md		results		  Untitled0.ipynb

# %%
# IMPORT
import torch
import os
# this module is for training and functions related to data preparation
from models.training import *
from models.cpnn import *
# this is for importing pretrain models.
from models.pretrain import *

#from models.cpnn_others import cPNNExp
#from models.cpnn_seq import cPNNSeq
#from models.cgru_double import cGRULinearDouble
#from models.clstm import *

import torch.nn.functional as F
import numpy as np
import pandas as pd
import pickle
import argparse
from torch.autograd import Variable
import pprint
import copy

# %%
# EDITABLE PARAMETERS
dataset = "sine_rw10_mode5_extended_6-6_1234"

# OTHER PARAMETERS
batch_size = 128
hidden_size = 250
seq_len = 10
# TODO
iterations = 1
loss_on_seq = False
freeze_inputs_weights = False
pretraining_samples = 0
pretraining_epochs = 0
write_weights = False
combination = False
model_type='GRU'
if model_type == "GRU":
    model_class = GRU_Model
else:
    model_class = cGRULinearDouble

path = os.path.join(
    "performance/pretrain_GRU"
)

# %%
df = pd.read_csv("datasets/datasets/sine_rw10_mode5_extended_6-6_1234.csv")
df_task = df[df["task"] == 4]
df_task = df_task.drop(columns="task")

# %%
Model = GRU_Model(input_size=2,
        device=torch.device("cpu"),
      	num_layers=1,
        hidden_size=250,
        output_size=2,
        batch_size=128,
          )
instance = cPNN(seq_len=seq_len)

# %%
if len(df_task) % batch_size == 0:
  n_batches = int(len(df_task) / batch_size)
else:
  n_batches = int(len(df_task) / batch_size) + 1
optimizer = torch.optim.Adam(Model.parameters(), lr=0.01)
loss_fn = torch.nn.CrossEntropyLoss(reduction="mean")
out_h = None
for j in range(0,5):
  for i in range(0, len(df_task), batch_size):
    x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
    y = list(df_task.iloc[i : i + batch_size, -1])
    if len(y) >= seq_len:
      x = np.array(x)
      y = list(y)
      x, y, _ = instance._load_batch(x, y)
      y_pred = Model(x)
      y_pred = get_samples_outputs(y_pred)
      pred, _ = get_pred_from_outputs(y_pred)
      loss = loss_fn(y_pred, y)
      # backward pass
      optimizer.zero_grad()
      loss.backward()
      # update weights
      optimizer.step()

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(Model.state_dict())
# Out:
# OrderedDict([   (   'gru.weight_ih_l0',
#                     tensor([[-0.1806, -0.0681],
#         [-0.7470, -0.3525],
#         [-0.5399, -0.6793],
#         ...,
#         [-0.0993, -0.0209],
#         [-0.3057,  0.1378],
#         [-0.8759, -0.0796]])),
#                 (   'gru.weight_hh_l0',
#                     tensor([[ 0.1140, -0.2292,  0.5598,  ..., -0.2384,  0.2873,  0.1222],
#         [-0.0027, -0.4374,  0.1670,  ...,  0.0591,  0.0709,  0.0327],
#         [-0.0796, -0.1987,  0.3587,  ..., -0.0487,  0.0426,  0.2037],
#         ...,
#         [-0.2096,  0.0584, -0.1452,  ..., -0.4858, -0.0066, -0.0344],
#         [-0.1099,  0.0944, -0.0276,  ..., -0.0772, -0.5610, -0.1718],
#          -1.6835e-01,  6.9169e-01,  2.8446e-01, -3.7397e-01,  1.1745e-01,
#           6.3418e-01,  8.5706e-02, -1.2509e-01, -1.7824e-01, -7.7222e-01,
#           7.1091e-02, -3.5230e-02,  2.5470e-02, -1.7212e-01, -3.0321e-01,
#          -4.4974e-02,  6.9714e-01,  1.6577e-01,  2.2468e-01, -1.5356e+00]])),
#                 ('linear.bias', tensor([ 0.1968, -0.1882]))])

# %%
# Save model
with open("performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4_hiiden250.pickle", "wb") as fp:
    pickle.dump(Model.state_dict(), fp)

# %% [markdown]
# ## trying to read the weights of the pretrain model

# %%
pretrain_model = PretrainModel(input_size=2,
        device=torch.device("cpu"),
      	num_layers=1,
        hidden_size=50,
        output_size=2,
        batch_size=128,
          )
with open("performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4.pickle", "rb") as fp:
    pretrain_model.load_state_dict(pickle.load(fp),strict=False)

# %%
import statistics

# %%
dataset1 = "sine_rw10_mode5_extended_6-6_1234"
pretrain_data = pd.read_csv(os.path.join("datasets/datasets", f"{dataset1}.csv"))
pretrain_data = pretrain_data[pretrain_data["task"] == 1]
pretrain_data.loc[:, 'task'] = 0
dataset2 = "sine_rw10_mode5_extended_16-16_1234"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset2}.csv"))

df = pretrain_data.append(df, ignore_index=True)

acc=[]
kappa=[]
for task in range(1, df["task"].max() + 1):
  acc[-1].append([])
  kappa[-1].append([])
  df_task = df[df["task"] == task]
  df_task = df_task.drop(columns="task")
  for i in range(0, len(df_task), batch_size):
      x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
      y = list(df_task.iloc[i : i + batch_size, -1])
      if len(y) >= seq_len:
        x = np.array(x)
        y = list(y)
        x, y, _ = instance._load_batch(x, y)
        y_pred = pretrain_model(x)
        y_pred = get_samples_outputs(y_pred)
        pred, _ = get_pred_from_outputs(y_pred)
        acc[-1][-1].append(accuracy_score(np.array(y),np.array(pred)))
        kappa[-1][-1].append(cohen_kappa(y,pred).item())
  print(statistics.mean(acc))
# Out:
# 0.35121882992327363
# 0.20711317135549873
# 0.6440776854219948
# 0.8104859335038364

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(pretrain_model.state_dict())
# Out:
# OrderedDict([   (   'gru.weight_ih_l0',
#                     tensor([[ 4.9395e-01,  7.2624e-01],
#         [-2.5023e-01, -1.5779e+00],
#         [ 4.2910e-02, -2.2821e-03],
#         [-2.7951e-01, -9.4084e-02],
#         [-4.2295e-01, -2.2655e-01],
#         [-7.1322e-01, -6.1827e-01],
#         [-1.0246e-02, -3.2005e-01],
#         [-4.1410e-01, -1.2440e+00],
#         [-7.2617e-01, -7.9609e-01],
#         [-5.6529e-01, -9.9232e-01],
#         [-5.3829e-01, -1.3724e+00],
#         [-4.4110e-01, -1.1477e+00],
#         [-4.6161e-01, -9.9819e-01],
#         [-3.8753e-01,  8.9283e-01],
#         [-6.3671e-01, -1.5068e+00],
#         [-7.4016e-01, -1.4635e+00],
#         [-2.6262e-01, -5.4108e-02],
#          1.6607e-01,  9.8904e-02, -5.2274e-01,  5.1580e-02,  2.0741e-02,
#          1.6024e-01, -2.2519e-01, -5.1179e-01,  1.0414e-01, -2.5748e-01,
#         -3.4203e-01,  1.8205e-01, -4.7831e-01, -3.1856e-01,  3.4689e-01,
#          1.7410e-01,  4.4540e-01, -3.1042e-01,  1.8671e-01, -2.1687e-01])),
#                 (   'linear.weight',
#                     tensor([[ 0.9405,  0.2271,  0.7698, -0.2114, -0.1298,  0.4095, -1.1612, -0.3689,
#           0.4152,  0.5684, -0.1521, -0.5008,  0.3154, -0.4925, -0.5354, -0.9929,
#           0.0493, -0.5868, -0.0939, -0.4699, -0.0962,  0.0346,  0.1684,  0.1373,
#           0.9437, -1.0162, -0.3080,  0.3015,  0.4012,  0.1756,  0.7329, -1.0198,
#           1.0351, -0.5327,  0.2654,  0.4709,  0.1626,  0.4671, -0.3614,  0.4215,
#           0.7278,  0.6765,  0.6108, -0.5089,  0.1037, -0.0873, -0.5458,  0.4520,
#          -0.7270,  1.0028],
#         [-0.8056, -0.1595, -0.8627,  0.0498,  0.2140, -0.2606,  0.9185,  0.4248,
#          -0.6264, -0.5880, -0.0679,  0.5931, -0.4610,  0.4918,  0.4800,  1.0122,
#          -0.0127,  0.5324, -0.1576,  0.4578,  0.1609, -0.0747, -0.1963, -0.0961,
#          -0.7924,  1.0687,  0.3024, -0.3455, -0.3541,  0.0045, -0.4906,  1.0083,
#          -0.8379,  0.4567, -0.2272, -0.3301, -0.0520, -0.4889,  0.3685, -0.5367,
#          -0.8136, -0.6951, -0.8154,  0.6257,  0.0099,  0.2187,  0.7137, -0.2799,
#           0.7222, -0.9372]])),
#                 ('linear.bias', tensor([-0.2302,  0.3455]))])

# %%
pretrain_model
# Out:
# PretrainModel(
#   (gru): GRU(2, 50, batch_first=True)
#   (linear): Linear(in_features=50, out_features=2, bias=True)
# )

# %%
x = copy.deepcopy(pretrain_model.state_dict())
for param_name in x:
  print(param_name)
  print(x[param_name].shape)
# Out:
# gru.weight_ih_l0
# torch.Size([150, 2])
# gru.weight_hh_l0
# torch.Size([150, 50])
# gru.bias_ih_l0
# torch.Size([150])
# gru.bias_hh_l0
# torch.Size([150])
# linear.weight
# torch.Size([2, 50])
# linear.bias
# torch.Size([2])

# %% [markdown]
# # Here first we need to train pure GRU or LSTM based models

# %%
batch_size = 128
hidden_size = 250
seq_len = 10
epoch_size=5
mask_init='uniform'
dataset1 = "sine_rw10_mode5_extended_6-6_1234"
pretrain_data = pd.read_csv(os.path.join("datasets/datasets", f"{dataset1}.csv"))
pretrain_data = pretrain_data[pretrain_data["task"] == 4]
pretrain_data.loc[:, 'task'] = 0
dataset2 = "sine_rw10_mode5_extended_16-16_1234"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset2}.csv"))

df = pretrain_data.append(df, ignore_index=True)


instance = cPB(seq_len=seq_len)
pretrain_model = GRU_Model(
        input_size=2,
        device=torch.device("cpu"),
      	num_layers=1,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
          )
acc=[]
kappa=[]
optimizer = torch.optim.Adam(pretrain_model.parameters(), lr=0.01)
loss_fn = torch.nn.CrossEntropyLoss(reduction="mean")
for task in range(0, df["task"].max() + 1):
  df_task = df[df["task"] == task]
  df_task = df_task.drop(columns="task")
  acc.append([])
  kappa.append([])
  for i in range(0, len(df_task), batch_size):
    x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
    y = list(df_task.iloc[i : i + batch_size, -1])
    if len(y) >= seq_len:
      x = np.array(x)
      y = list(y)
      x, y, _ = instance._load_batch(x, y)
      y_pred = pretrain_model(x)
      y_pred = get_samples_outputs(y_pred)
      pred, _ = get_pred_from_outputs(y_pred)
      acc[-1].append(accuracy_score(np.array(y),np.array(pred)))
      kappa[-1].append(cohen_kappa(y,pred).item())
      for j in range(0,5):
        loss = loss_fn(y_pred, y)
        # backward pass
        optimizer.zero_grad()
        loss.backward()
        # update weights
        optimizer.step()
        y_pred = pretrain_model(x)
        y_pred = get_samples_outputs(y_pred)
        pred, _ = get_pred_from_outputs(y_pred)
# Out:
# <ipython-input-13-a92507baab30>:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = pretrain_data.append(df, ignore_index=True)
# hidden_size 50

# %%
np.array(acc).shape
# Out:
# (5, 391)

# %%
pd.DataFrame(acc).to_csv('results/acc-16_16-1234-cGRU-t4-hidden250.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-16_16-1234-cGRU-t4-hidden250.csv', index=False)

# %% [markdown]
# #**From now on, the part for adding mask will be implemented:**

# %% [markdown]
# ##The first part is the implementing of the frozen pretrained model and then testing on test dataset.

# %%
batch_size = 128
hidden_size = 50
seq_len = 10
epoch_size=5
mask_init='uniform'
dataset = "sine_rw10_mode5_extended_16-16_1432"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
pretrain_model_addr='performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4.pickle'

number_of_tasks=4
instance = cPB(seq_len=seq_len)
pretrain_model = PretrainModel(
        input_size=2,
        device=torch.device("cpu"),
      	num_layers=1,
        hidden_size=hidden_size,
        output_size=2,
        batch_size=batch_size,
          )
with open(pretrain_model_addr, "rb") as fp:
    		    pretrain_model.load_state_dict(pickle.load(fp),strict=False)
acc=[]
kappa=[]
for task in range(1, df["task"].max() + 1):
  df_task = df[df["task"] == task]
  df_task = df_task.drop(columns="task")
  acc.append([])
  kappa.append([])
  for i in range(0, len(df_task), batch_size):
    x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
    y = list(df_task.iloc[i : i + batch_size, -1])
    if len(y) >= seq_len:
      x = np.array(x)
      y = list(y)
      x, y, _ = instance._load_batch(x, y)
      y_pred = pretrain_model(x)
      y_pred = get_samples_outputs(y_pred)
      pred, _ = get_pred_from_outputs(y_pred)
      acc[-1].append(accuracy_score(np.array(y),np.array(pred)))
      kappa[-1].append(cohen_kappa(y,pred).item())
# Out:
# hidden_size 50
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dd6a75e95e4c> in <cell line: 12>()
#      10 number_of_tasks=4
#      11 instance = cPB(seq_len=seq_len)
# ---> 12 pretrain_model = PretrainModel(
#      13         input_size=2,
#      14         device=torch.device("cpu"),
#
# NameError: name 'PretrainModel' is not defined

# %%
pd.DataFrame(acc).to_csv('results/acc-CPB-16_16-frozen-1432-t4.csv', index=False)
pd.DataFrame(kappa).to_csv('results/kappa-CPB-16_16-frozen-1432-t4.csv', index=False)

# %%
df1 = np.array(pd.read_csv('results/kappa-cpnn-pretrain-t4-16_16-1234.csv'))
df2 = np.array(pd.read_csv('results/kappa-cpnn-pretrain-t4-16_16-1432.csv'))
df3 = np.array(pd.read_csv('results/kappa-cpnn-pretrain-t4-16_16-2143.csv'))
df4 = np.array(pd.read_csv('results/kappa-cpnn-pretrain-t4-16_16-2341.csv'))

def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))
# Create a DataFrame from the converted data
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1],4*all_x.shape[1]]
x = list(range(1,5*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],5):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3],y[i+4]),axis=0), label= label_list[int(i/5)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative cohen kappa Over Batches for CPNN model')
plt.legend()
plt.show()
# Out:
# 0    0.668472
# 1    0.700355
# 2    0.656562
# 3    0.812521
# 4    0.666689
# dtype: float64
# 0    0.658617
# 1    0.674011
# 2    0.670207
# 3    0.794875
# 4    0.687306
# dtype: float64
# 0    0.663672
# 1    0.640572
# 2    0.658128
# 3    0.719156
# 4    0.803571
# dtype: float64
# 0    0.658728
# 1    0.641481
# 2    0.670671
# 3    0.705178
# 4    0.805178
# dtype: float64

# %% [markdown]
# ##Now we also train the pretrain model for each task of the test dataset.

# %%
batch_size = 128
hidden_size = 250
seq_len = 10
epoch_size=5
lr = 0.01
number_of_tasks=4
mask_selection_NofBatch = 50
mask_init='uniform'
dataset = "sine_rw10_mode5_extended_16-16_2341"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
pretrain_model_addr='performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4_hiiden250.pickle'
mask_weights=[]

model=cPB(model_class=PiggyBackGRU, lr = lr ,hidden_size=hidden_size, seq_len=seq_len, pretrain_model_addr=pretrain_model_addr,
           mask_weights=mask_weights, mask_init=mask_init, number_of_tasks=number_of_tasks,epoch_size=epoch_size)
iteration=1
# first loop for the iterations, for now it is just 1 iteration.
for iter in range(0,iteration):
  # loop for each task
  for task in range(1, df["task"].max() + 1):
    df_task = df[df["task"] == task]
    df_task = df_task.drop(columns="task")
    # loop based on each batch of data
    batch_cont=0
    model.weights_copy(task)
    for i in range(0, len(df_task), batch_size):
      x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
      y = list(df_task.iloc[i : i + batch_size, -1])
      if batch_cont<mask_selection_NofBatch:
        for mask_index in range (0, task):
          model.predict_many(x,y,mask_index)
          model.learn_many(x,y,mask_index)
        batch_cont+=1
      elif batch_cont==mask_selection_NofBatch:
        best_mask_index=model.add_new_column()
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
        batch_cont+=1
      elif batch_cont>mask_selection_NofBatch:
        batch_cont+=1
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
    model.save_final_metrics(task,best_mask_index)
    model.final_weights_saving()
  model.plotting()
# Out:
# hidden_size 250
# list of accuracies that used for evaluating and selecting the models =  [0.69796875]
# list of kappa values that used for evaluating and selecting the models =  [0.40581794]
# index of selcted mask for this task 0
# All batches Accuracy=  0.8122322570332481
# All batches cohen kappa=  0.624905918841548
# list of accuracies that used for evaluating and selecting the models =  [0.78703125 0.8909375 ]
# list of kappa values that used for evaluating and selecting the models =  [0.5772056  0.77177361]
# index of selcted mask for this task 1
# All batches Accuracy=  0.9030290920716113
# All batches cohen kappa=  0.8028588836531505
# list of accuracies that used for evaluating and selecting the models =  [0.6778125  0.9265625  0.90265625]
# list of kappa values that used for evaluating and selecting the models =  [0.37155794 0.84831021 0.80117842]
# index of selcted mask for this task 1
# All batches Accuracy=  0.8885429987212277
# All batches cohen kappa=  0.7750760635832692
# list of accuracies that used for evaluating and selecting the models =  [0.81375    0.8646875  0.8634375  0.85015625]
# list of kappa values that used for evaluating and selecting the models =  [0.63484363 0.71420473 0.71584943 0.69657499]
# index of selcted mask for this task 1
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# All batches Accuracy=  0.9077765345268543
# All batches cohen kappa=  0.8119150998995013
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pd.DataFrame(model.all_batch_acc).to_csv('results/acc-CPB-16_16-2341-t4_hidden250.csv', index=False)
pd.DataFrame(model.all_batch_kappa).to_csv('results/kappa-CPB-16_16-2341-t4_hidden250.csv', index=False)

# %%
batch_size = 128
hidden_size = 250
seq_len = 10
epoch_size=5
lr = 0.01
number_of_tasks=4
mask_selection_NofBatch = 50
mask_init='uniform'
dataset = "sine_rw10_mode5_extended_16-16_2143"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
pretrain_model_addr='performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4_hiiden250.pickle'
mask_weights=[]

model=cPB(model_class=PiggyBackGRU, lr = lr ,hidden_size=hidden_size, seq_len=seq_len, pretrain_model_addr=pretrain_model_addr,
           mask_weights=mask_weights, mask_init=mask_init, number_of_tasks=number_of_tasks,epoch_size=epoch_size)
iteration=1
# first loop for the iterations, for now it is just 1 iteration.
for iter in range(0,iteration):
  # loop for each task
  for task in range(1, df["task"].max() + 1):
    df_task = df[df["task"] == task]
    df_task = df_task.drop(columns="task")
    # loop based on each batch of data
    batch_cont=0
    model.weights_copy(task)
    for i in range(0, len(df_task), batch_size):
      x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
      y = list(df_task.iloc[i : i + batch_size, -1])
      if batch_cont<mask_selection_NofBatch:
        for mask_index in range (0, task):
          model.predict_many(x,y,mask_index)
          model.learn_many(x,y,mask_index)
        batch_cont+=1
      elif batch_cont==mask_selection_NofBatch:
        best_mask_index=model.add_new_column()
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
        batch_cont+=1
      elif batch_cont>mask_selection_NofBatch:
        batch_cont+=1
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
    model.save_final_metrics(task,best_mask_index)
    model.final_weights_saving()
  model.plotting()
# Out:
# hidden_size 250
# list of accuracies that used for evaluating and selecting the models =  [0.65875]
# list of kappa values that used for evaluating and selecting the models =  [0.31502129]
# index of selcted mask for this task 0
# All batches Accuracy=  0.8021978900255755
# All batches cohen kappa=  0.6036503913042985
# list of accuracies that used for evaluating and selecting the models =  [0.8275    0.9178125]
# list of kappa values that used for evaluating and selecting the models =  [0.658827   0.82632106]
# index of selcted mask for this task 1
# All batches Accuracy=  0.8917758951406649
# All batches cohen kappa=  0.7801163675230177
# list of accuracies that used for evaluating and selecting the models =  [0.78375    0.88       0.85453125]
# list of kappa values that used for evaluating and selecting the models =  [0.56600922 0.75479464 0.70399493]
# index of selcted mask for this task 1
# All batches Accuracy=  0.8768182544757033
# All batches cohen kappa=  0.751722184860188
# list of accuracies that used for evaluating and selecting the models =  [0.80390625 0.9221875  0.923125   0.9296875 ]
# list of kappa values that used for evaluating and selecting the models =  [0.60875131 0.84031647 0.8431626  0.85674909]
# index of selcted mask for this task 3
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# All batches Accuracy=  0.9121803069053709
# All batches cohen kappa=  0.821823153082672
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pd.DataFrame(model.all_batch_acc).to_csv('results/acc-CPB-16_16-2143-t4_hidden250.csv', index=False)
pd.DataFrame(model.all_batch_kappa).to_csv('results/kappa-CPB-16_16-2143-t4_hidden250.csv', index=False)

# %%
batch_size = 128
hidden_size = 250
seq_len = 10
epoch_size=5
lr = 0.01
number_of_tasks=4
mask_selection_NofBatch = 50
mask_init='uniform'
dataset = "sine_rw10_mode5_extended_16-16_1432"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
pretrain_model_addr='performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4_hiiden250.pickle'
mask_weights=[]

model=cPB(model_class=PiggyBackGRU, lr = lr ,hidden_size=hidden_size, seq_len=seq_len, pretrain_model_addr=pretrain_model_addr,
           mask_weights=mask_weights, mask_init=mask_init, number_of_tasks=number_of_tasks,epoch_size=epoch_size)
iteration=1
# first loop for the iterations, for now it is just 1 iteration.
for iter in range(0,iteration):
  # loop for each task
  for task in range(1, df["task"].max() + 1):
    df_task = df[df["task"] == task]
    df_task = df_task.drop(columns="task")
    # loop based on each batch of data
    batch_cont=0
    model.weights_copy(task)
    for i in range(0, len(df_task), batch_size):
      x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
      y = list(df_task.iloc[i : i + batch_size, -1])
      if batch_cont<mask_selection_NofBatch:
        for mask_index in range (0, task):
          model.predict_many(x,y,mask_index)
          model.learn_many(x,y,mask_index)
        batch_cont+=1
      elif batch_cont==mask_selection_NofBatch:
        best_mask_index=model.add_new_column()
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
        batch_cont+=1
      elif batch_cont>mask_selection_NofBatch:
        batch_cont+=1
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
    model.save_final_metrics(task,best_mask_index)
    model.final_weights_saving()
  model.plotting()
# Out:
# hidden_size 250
# list of accuracies that used for evaluating and selecting the models =  [0.655]
# list of kappa values that used for evaluating and selecting the models =  [0.31602026]
# index of selcted mask for this task 0
# All batches Accuracy=  0.8643502237851662
# All batches cohen kappa=  0.7283304139812146
# list of accuracies that used for evaluating and selecting the models =  [0.7696875  0.84640625]
# list of kappa values that used for evaluating and selecting the models =  [0.53823477 0.68524274]
# index of selcted mask for this task 1
# All batches Accuracy=  0.8715872762148337
# All batches cohen kappa=  0.7411256740751017
# list of accuracies that used for evaluating and selecting the models =  [0.75203125 0.9221875  0.93      ]
# list of kappa values that used for evaluating and selecting the models =  [0.50129588 0.84097036 0.85673748]
# index of selcted mask for this task 2
# All batches Accuracy=  0.9110294117647059
# All batches cohen kappa=  0.8206701393779892
# list of accuracies that used for evaluating and selecting the models =  [0.7603125  0.8653125  0.86984375 0.86      ]
# list of kappa values that used for evaluating and selecting the models =  [0.51842065 0.72469286 0.73230715 0.71128263]
# index of selcted mask for this task 2
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# All batches Accuracy=  0.8516743925831202
# All batches cohen kappa=  0.7004782735081889
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pd.DataFrame(model.all_batch_acc).to_csv('results/acc-CPB-16_16-1432-t4_hidden250.csv', index=False)
pd.DataFrame(model.all_batch_kappa).to_csv('results/kappa-CPB-16_16-1432-t4_hidden250.csv', index=False)

# %%
batch_size = 128
hidden_size = 250
seq_len = 10
epoch_size=5
lr = 0.01
number_of_tasks=4
mask_selection_NofBatch = 50
mask_init='uniform'
dataset = "sine_rw10_mode5_extended_16-16_2143"
df = pd.read_csv(os.path.join("datasets/datasets", f"{dataset}.csv"))
pretrain_model_addr='performance/pretrain/pretrain_mode_gru_sine_rw10_mode5_extended_6-6_1234_4_hiiden250.pickle'
mask_weights=[]

model=cPB(model_class=PiggyBackGRU, lr = lr ,hidden_size=hidden_size, seq_len=seq_len, pretrain_model_addr=pretrain_model_addr,
           mask_weights=mask_weights, mask_init=mask_init, number_of_tasks=number_of_tasks,epoch_size=epoch_size)
iteration=1
# first loop for the iterations, for now it is just 1 iteration.
for iter in range(0,iteration):
  # loop for each task
  for task in range(1, df["task"].max() + 1):
    df_task = df[df["task"] == task]
    df_task = df_task.drop(columns="task")
    # loop based on each batch of data
    batch_cont=0
    model.weights_copy(task)
    for i in range(0, len(df_task), batch_size):
      x = df_task.iloc[i : i + batch_size, 0:-1].values.astype(np.float32)
      y = list(df_task.iloc[i : i + batch_size, -1])
      if batch_cont<mask_selection_NofBatch:
        for mask_index in range (0, task):
          model.predict_many(x,y,mask_index)
          model.learn_many(x,y,mask_index)
        batch_cont+=1
      elif batch_cont==mask_selection_NofBatch:
        best_mask_index=model.add_new_column()
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
        batch_cont+=1
      elif batch_cont>mask_selection_NofBatch:
        batch_cont+=1
        model.predict_many(x,y,best_mask_index)
        model.learn_many(x,y,best_mask_index)
    model.save_final_metrics(task,best_mask_index)
    model.final_weights_saving()
  model.plotting()
# Out:
# hidden_size 250
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-54636779c2ad> in <cell line: 18>()
#      30         for mask_index in range (0, task):
#      31           model.predict_many(x,y,mask_index)
# ---> 32           model.learn_many(x,y,mask_index)
#      33         batch_cont+=1
#      34       elif batch_cont==mask_selection_NofBatch:
#
# /content/drive/My Drive/Thesis/CPNN_PiggyBack/models/training.py in learn_many(self, x, y, task_number)
#     137         # backward pass
#     138         optimizer.zero_grad()
# --> 139         loss.backward(retain_graph=True)
#     140         # update weights
#     141         optimizer.step()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(self, *args)
#     274
#     275 class BackwardCFunction(_C._FunctionBase, FunctionCtx, _HookMixin):
# --> 276     def apply(self, *args):
#     277         # _forward_cls is defined by derived class
#     278         # The user should define either backward or vjp but never both.
#
# KeyboardInterrupt:

# %%
pd.DataFrame(model.all_batch_acc).to_csv('results/acc-CPB-16_16-2143-t4_hidden250.csv', index=False)
pd.DataFrame(model.all_batch_kappa).to_csv('results/kappa-CPB-16_16-2143-t4_hidden250.csv', index=False)

# %%
df1 = np.array(pd.read_csv('results/kappa-16_16-1234-4.csv'))
df2 = np.array(pd.read_csv('results/kappa-16_16-1432-4.csv'))
df3 = np.array(pd.read_csv('results/kappa-16_16-2143-4.csv'))
df4 = np.array(pd.read_csv('results/kappa-16_16-2341-4.csv'))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches')
plt.legend()
plt.show()
