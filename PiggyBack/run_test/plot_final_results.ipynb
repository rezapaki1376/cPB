# %%
from google.colab import drive
drive.mount('/content/drive')
# going to the repository of this note book
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# CSS   datasets	models	     push_to_git.ipynb	requirements.txt  run_test
# data  lab	performance  README.md		results		  Untitled0.ipynb

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1) plot CPB accuracy and cohen kappa

# %%
df1 = np.array(pd.read_csv('results/acc-CPB-16_16-1234-t1_hidden250.csv'))
df2 = np.array(pd.read_csv('results/acc-CPB-16_16-1234-t2_hidden250.csv'))
df3 = np.array(pd.read_csv('results/acc-CPB-16_16-1234-t3_hidden250.csv'))
df4 = np.array(pd.read_csv('results/acc-CPB-16_16-1234-t4_hidden250.csv'))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['CPB Task 1','CPB Task 2','CPB Task 3','CPB Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches on Dataset 1432')
plt.legend()
plt.show()

# %%
df1 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t1.csv'))
df2 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t2.csv'))
df3 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t3.csv'))
df4 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t4.csv'))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['CPB Task 1','CPB Task 2','CPB Task 3','CPB Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches on Dataset 1432')
plt.legend()
plt.show()

# %% [markdown]
# ## 2) plot CPNN accuracy and cohen kappa

# %%
df1 = np.array(pd.read_csv('results/acc-cpnn-16_16-1234.csv'))
df2 = np.array(pd.read_csv('results/acc-cpnn-16_16-1432.csv'))
df3 = np.array(pd.read_csv('results/acc-cpnn-16_16-2143.csv'))
df4 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341.csv'))

def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))
# Create a DataFrame from the converted data
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches on different configrations of 16_16')
plt.legend()
plt.show()
# Out:
# 0    0.894273
# 1    0.808304
# 2    0.943626
# 3    0.869685
# dtype: float64
# 0    0.894377
# 1    0.813559
# 2    0.937712
# 3    0.882609
# dtype: float64
# 0    0.785930
# 1    0.869198
# 2    0.869138
# 3    0.942160
# dtype: float64
# 0    0.792527
# 1    0.864854
# 2    0.870912
# 3    0.939398
# dtype: float64

# %%
df1 = np.array(pd.read_csv('results/kappa-cpnn-16_16-1234.csv'))
df2 = np.array(pd.read_csv('results/kappa-cpnn-16_16-1432.csv'))
df3 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2143.csv'))
df4 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341.csv'))

def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))
# Create a DataFrame from the converted data
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches on different configrations of 16_16')
plt.legend()
plt.show()
# Out:
# 0    0.787291
# 1    0.614259
# 2    0.885636
# 3    0.737420
# dtype: float64
# 0    0.787386
# 1    0.625708
# 2    0.873236
# 3    0.763072
# dtype: float64
# 0    0.571012
# 1    0.737712
# 2    0.736835
# 3    0.882501
# dtype: float64
# 0    0.582833
# 1    0.729756
# 2    0.740027
# 3    0.876484
# dtype: float64

# %% [markdown]
# ## 3) plot CPNN accuracy and cohen kappa with a pretrained model

# %%
df1 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341-pretrain-t1.csv'))
df2 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341-pretrain-t2.csv'))
df3 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341-pretrain-t3.csv'))
df4 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341-pretrain-t4.csv'))

def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))
# Create a DataFrame from the converted data
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['CPNN Task 1','CPNN Task 2','CPNN Task 3','CPNN Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],5):
  ax.plot(x, np.concatenate((y[i+1],y[i+2],y[i+3],y[i+4]),axis=0), label= label_list[int(i/5)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches for CPNN model on Dataset 2341')
plt.legend()
plt.show()
# Out:
# 0    0.905147
# 1    0.862464
# 2    0.877250
# 3    0.883156
# 4    0.934887
# dtype: float64
# 0    0.878081
# 1    0.874996
# 2    0.851539
# 3    0.900819
# 4    0.933548
# dtype: float64
# 0    0.882197
# 1    0.865741
# 2    0.828780
# 3    0.898861
# 4    0.911425
# dtype: float64
# 0    0.883508
# 1    0.862380
# 2    0.845277
# 3    0.909431
# 4    0.920912
# dtype: float64

# %%
df1 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341-pretrain-t1.csv'))
df2 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341-pretrain-t2.csv'))
df3 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341-pretrain-t3.csv'))
df4 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341-pretrain-t4.csv'))

def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))
# Create a DataFrame from the converted data
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['CPNN Task 1','CPNN Task 2','CPNN Task 3','CPNN Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],5):
  ax.plot(x, np.concatenate((y[i+1],y[i+2],y[i+3],y[i+4]),axis=0), label= label_list[int(i/5)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches for CPNN model on Dataset 2341')
plt.legend()
plt.show()
# Out:
# 0    0.807632
# 1    0.720884
# 2    0.753482
# 3    0.763996
# 4    0.868127
# dtype: float64
# 0    0.753526
# 1    0.748414
# 2    0.703438
# 3    0.799196
# 4    0.865526
# dtype: float64
# 0    0.765546
# 1    0.728621
# 2    0.655699
# 3    0.795587
# 4    0.822113
# dtype: float64
# 0    0.767068
# 1    0.723712
# 2    0.688405
# 3    0.816462
# 4    0.840789
# dtype: float64

# %% [markdown]
# ## 4) plot CPNN accuracy and cohen kappa while we have not any pre-trainede model

# %%
df1 = np.array(pd.read_csv('results/acc-cpnn-16_16-1234.csv'))
df2 = np.array(pd.read_csv('results/acc-cpnn-16_16-1432.csv'))
df3 = np.array(pd.read_csv('results/acc-cpnn-16_16-2143.csv'))
df4 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341.csv'))
def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches')
plt.legend()
plt.show()

# %%
df1 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t1.csv'))
df2 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t2.csv'))
df3 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t3.csv'))
df4 = np.array(pd.read_csv('results/kappa-CPB-16_16-1432-t4.csv'))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches')
plt.legend()
plt.show()

# %% [markdown]
# ## 5) plot accuracy and cohen kappa while we have a frozen pre-trained model and not to train on test set

# %%
df1 = np.array(pd.read_csv('results/acc-CPB-16_16-frozen-1234-t1.csv'))
df2 = np.array(pd.read_csv('results/acc-CPB-16_16-frozen-1234-t2.csv'))
df3 = np.array(pd.read_csv('results/acc-CPB-16_16-frozen-1234-t3.csv'))
df4 = np.array(pd.read_csv('results/acc-CPB-16_16-frozen-1234-t4.csv'))
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))

all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['Task 1','Task 2','Task 3','Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches on dataset 16_6_1234')
plt.legend()
plt.show()
# Out:
# [0.58738411 0.71830643 0.41424632 0.26465793]
# [0.65874361 0.81446611 0.34533248 0.1701047 ]
# [0.42779731 0.25284127 0.57466432 0.76012628]
# [0.34150016 0.14974824 0.65638587 0.8622962 ]

# %%
df1 = np.array(pd.read_csv('results/kappa-CPB-16_16-frozen-1234-t1.csv'))
df2 = np.array(pd.read_csv('results/kappa-CPB-16_16-frozen-1234-t2.csv'))
df3 = np.array(pd.read_csv('results/kappa-CPB-16_16-frozen-1234-t3.csv'))
df4 = np.array(pd.read_csv('results/kappa-CPB-16_16-frozen-1234-t4.csv'))
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['Task 1','Task 2','Task 3','Task 4']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches on Dataset 16_16_1234')
plt.legend()
plt.show()
# Out:
# [ 0.18032818  0.43535489 -0.16439937 -0.45487321]
# [ 0.32187176  0.62756495 -0.29919617 -0.64463465]
# [-0.14777714 -0.4781863   0.14645017  0.51560024]
# [-0.31640475 -0.68342018  0.31171285  0.72149587]

# %% [markdown]
# ## Running pure GRU network

# %%
df1 = np.array(pd.read_csv('results/acc-16_16-1234-puretrain.csv'))
df2 = np.array(pd.read_csv('results/acc-16_16-1432-puretrain.csv'))
df3 = np.array(pd.read_csv('results/acc-16_16-2143-puretrain.csv'))
df4 = np.array(pd.read_csv('results/acc-16_16-2341-puretrain.csv'))
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Cumulative Accuracy Over Batches on Dataset 16_16 with different configurations')
plt.legend()
plt.show()
# Out:
# [0.89393382 0.81329124 0.9271899  0.82969949]
# [0.89869725 0.8230219  0.92649057 0.80949089]
# [0.78824728 0.91804668 0.82096787 0.93112612]
# [0.78897458 0.88546595 0.82616688 0.91932545]

# %%
df1 = np.array(pd.read_csv('results/kappa-16_16-1234-puretrain.csv'))
df2 = np.array(pd.read_csv('results/kappa-16_16-1432-puretrain.csv'))
df3 = np.array(pd.read_csv('results/kappa-16_16-2143-puretrain.csv'))
df4 = np.array(pd.read_csv('results/kappa-16_16-2341-puretrain.csv'))
print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['16_16-1234','16_16-1432','16_16-2143','16_16-2341']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Cumulative Cohen Kappa Over Batches on Dataset 16_16 with different configurations')
plt.legend()
plt.show()
# Out:
# [0.78721864 0.62543829 0.85265143 0.6573622 ]
# [0.796636   0.64575288 0.8507079  0.61568478]
# [0.57680898 0.8354804  0.64176263 0.8603673 ]
# [0.5775678  0.77016623 0.65119079 0.83810213]

# %% [markdown]
# # Now we want to find the best model based on Cohen Kappa. By doing so we compare models after 50 batches and end of the task to find the best model.

# %%
df1 = np.array(pd.read_csv('results/kappa-CPB-16_16-2341-t1.csv'))
df2 = np.array(pd.read_csv('results/kappa-CPB-16_16-2341-t2.csv'))
df3 = np.array(pd.read_csv('results/kappa-CPB-16_16-2341-t3.csv'))
df4 = np.array(pd.read_csv('results/kappa-CPB-16_16-2341-t4.csv'))
all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
y.shape
for i in range(0,y.shape[0],4):
  print(' Average after 50 batches = ',(y[i][49]+y[i+1][49]+y[i+2][49]+y[i+3][49])/4)
  print(' Average at the end of the task = ',(y[i][-1]+y[i+1][-1]+y[i+2][-1]+y[i+3][-1])/4)
# Out:
#  Average after 50 batches =  0.6284640478435904
#  Average at the end of the task =  0.6748772048453331
#  Average after 50 batches =  0.61382382275071
#  Average at the end of the task =  0.6584149297497109
#  Average after 50 batches =  0.6359060785640032
#  Average at the end of the task =  0.6642602206216148
#  Average after 50 batches =  0.6378419617284089
#  Average at the end of the task =  0.6898044229132574

# %%
df1 = np.array(pd.read_csv('results/kappa-16_16-1234-puretrain.csv'))
df2 = np.array(pd.read_csv('results/kappa-16_16-1432-puretrain.csv'))
df3 = np.array(pd.read_csv('results/kappa-16_16-2143-puretrain.csv'))
df4 = np.array(pd.read_csv('results/kappa-16_16-2341-puretrain.csv'))


all_x=np.concatenate((df1,df2,df3,df4),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
y.shape
for i in range(0,y.shape[0],4):

  print(' Average after 50 batches = ',(y[i][49]+y[i+1][49]+y[i+2][49]+y[i+3][49])/4)
  print(' Average at the end of the task = ',(y[i][-1]+y[i+1][-1]+y[i+2][-1]+y[i+3][-1])/4)
# Out:
#  Average after 50 batches =  0.524651153399609
#  Average at the end of the task =  0.7306676421932581
#  Average after 50 batches =  0.5338291673734784
#  Average at the end of the task =  0.727195388780397
#  Average after 50 batches =  0.5417598221078515
#  Average at the end of the task =  0.7286048269618656
#  Average after 50 batches =  0.44996315964031963
#  Average at the end of the task =  0.7092567377960752

# %% [markdown]
# # plotting the best models

# %%
def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
#df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df1 = np.array(pd.read_csv('results/kappa-16_16-2341-cGRU-t4-hidden250.csv'))
#df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df1 = np.array(df1)
mean_first_50 = np.mean(df1[:, :50], axis=1)

mean_whole_row = np.mean(df1, axis=1)

print(mean_first_50)

print(mean_whole_row)
# Out:
# [0.56325432 0.46875817 0.47184738 0.4760535  0.65352476]
# [0.79964203 0.65951012 0.77346096 0.62784175 0.77601425]

# %%
df3.shape
# Out:
# (4, 391)

# %%
df4.shape
# Out:
# (4, 391)

# %%
df1 = np.array(pd.read_csv('results/acc-CPB-16_16-2341-t4_hidden250.csv'))
df2 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341-pretrain-t4.csv').drop(0))
df3 = np.array(pd.read_csv('results/acc-cpnn-16_16-2341.csv'))
df4 = np.array(pd.read_csv('results/acc-16_16-2341-cGRU-t2-hidden250.csv').drop(0))
df5 = np.array(pd.read_csv('results/acc-16_16-2341-puretrain.csv'))


def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
#df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
#df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))

print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))
print( df5.mean(axis=1))
all_x=np.concatenate((df1,df2,df3,df4,df5),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['Best CPB','Best CPNN-Pretrain','CPNN','Best cGRU','GRU']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Accuracy')
plt.title('Ploting best models configurations on Dataset 16_16_2341')
plt.legend()
plt.show()
# Out:
# [0.81223226 0.90302909 0.888543   0.90777653]
# 0    0.860234
# 1    0.852997
# 2    0.889146
# 3    0.932081
# dtype: float64
# 0    0.809898
# 1    0.888943
# 2    0.873445
# 3    0.952510
# dtype: float64
# [0.86430627 0.88571371 0.81311541 0.90268942]
# [0.78897458 0.88546595 0.82616688 0.91932545]

# %%
df1 = np.array(pd.read_csv('results/kappa-CPB-16_16-2341-t4_hidden250.csv'))
df2 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341-pretrain-t4.csv').drop(0))
df3 = np.array(pd.read_csv('results/kappa-cpnn-16_16-2341.csv'))
df4 = np.array(pd.read_csv('results/kappa-16_16-2341-cGRU-t2-hidden250.csv').drop(0))
df5 = np.array(pd.read_csv('results/kappa-16_16-2341-puretrain.csv'))
def string_to_float(s):
    return float(s.strip('[]'))

# Apply the conversion function to each element in the array
#df1 = pd.DataFrame(np.vectorize(string_to_float)(df1))
df2 = pd.DataFrame(np.vectorize(string_to_float)(df2))
df3 = pd.DataFrame(np.vectorize(string_to_float)(df3))
#df4 = pd.DataFrame(np.vectorize(string_to_float)(df4))

print( df1.mean(axis=1))
print( df2.mean(axis=1))
print( df3.mean(axis=1))
print( df4.mean(axis=1))
all_x=np.concatenate((df1,df2,df3,df4,df5),axis=0)
y = np.cumsum(all_x, axis=1) / np.arange(1, all_x.shape[1] + 1)
vertical_lines_x = [all_x.shape[1], 2*all_x.shape[1], 3*all_x.shape[1]]
x = list(range(1,4*all_x.shape[1] + 1))
fig, ax = plt.subplots(figsize=(12, 4))
ax.margins(x=0.0)
label_list=['Best CPB','Best CPNN-Pretrain','CPNN','Best cGRU','GRU']

for i in vertical_lines_x:
  plt.axvline(x=i, color='#D3D3D3', linestyle='-')

for i in range(0,y.shape[0],4):
  ax.plot(x, np.concatenate((y[i],y[i+1],y[i+2],y[i+3]),axis=0), label= label_list[int(i/4)])
plt.xlabel('Batch Number')
plt.ylabel('Cumulative Cohen Kappa')
plt.title('Ploting best models configurations on Dataset 16_16_2341')
plt.legend()
plt.show()
# Out:
# [0.62490592 0.80285888 0.77507606 0.8119151 ]
# 0    0.720201
# 1    0.704488
# 2    0.777080
# 3    0.862234
# dtype: float64
# 0    0.618480
# 1    0.777309
# 2    0.746096
# 3    0.903343
# dtype: float64
# [0.72677994 0.77086261 0.62690406 0.80326366]
