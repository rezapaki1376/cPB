# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# data	  lab	  performance	     README.md	       run_test
# datasets  models  push_to_git.ipynb  requirements.txt

# %%
username = 'rezapaki1376'
email = 'paki.reza@yahoo.com'
repo = 'CPNN_PiggyBack'
token = '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'

# %%
# !git add --all

# %%
git config --global user.email "paki.reza@yahoo.com"
git config --global user.name "rezapaki1376"

# !git commit -a -m "testing colab push "
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ed5017bbf54a.(none)')

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (push)

# %%
# !git remote set-url origin https://github.com/rezapaki1376/CPNN_PiggyBack

# %%
# !git remote -v
# Out:
# origin	https://github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://github.com/rezapaki1376/CPNN_PiggyBack (push)

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://github.com/rezapaki1376/CPNN_PiggyBack'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'CPNN_PiggyBack'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (3/3), done.
