# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# CSS  PiggyBack	push_to_git.ipynb  README.md  requirements.txt	Untitled0.ipynb

# %%
username = 'rezapaki1376'
email = 'paki.reza@yahoo.com'
repo = 'CPNN_PiggyBack'
token = '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'

# %%
# !git add --all

# %%
# !git config --global user.email "paki.reza@yahoo.com"
# !git config --global user.name "rezapaki1376"

# !git commit -a -m "piggyback folder reorganized and Css models added"
# !git push origin
# Out:
# [main 96fe81b] piggyback folder reorganized and Css models added
#  1149 files changed, 35646453 insertions(+), 271 deletions(-)
#  create mode 100644 CSS/Untitled0.ipynb
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n10_+.csv (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n10_+.pkl (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n10_-.csv (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n10_-.pkl (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n11_+.csv (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n11_+.pkl (100%)
#  rename {datasets => CSS/datasets}/datasets/extended_functions/sine_rw10_mode5_complex_n11_-.csv (100%)
# ...

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (push)
