# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# CSS  PiggyBack	push_to_git.ipynb  README.md  requirements.txt	Untitled0.ipynb

# %%
username = 'rezapaki1376'
email = 'paki.reza@yahoo.com'
repo = 'CPNN_PiggyBack'
token = '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'

# %%
# !git add --all

# %%
# !git config --global user.email "paki.reza@yahoo.com"
# !git config --global user.name "rezapaki1376"

# !git commit -a -m "piggyback folder reorganized and Css models added"
# !git push origin
# Out:
# [main 3a05823] piigyback based lstm classes updated
#  36 files changed, 9 insertions(+), 6 deletions(-)
#  delete mode 100644 .DS_Store
#  delete mode 100644 iris-model-full.pth
#  delete mode 100644 iris-model.pickle
#  create mode 100644 performance/pretrain/pretrain_mode_gru_hidden100_sine_rw10_mode5_extended_6-6_1234_1.pickle
#  create mode 100644 performance/pretrain/pretrain_mode_gru_hidden150_sine_rw10_mode5_extended_6-6_1234_1.pickle
#  create mode 100644 performance/pretrain/pretrain_mode_gru_hidden200_sine_rw10_mode5_extended_6-6_1234_1.pickle
#  create mode 100644 performance/pretrain/pretrain_mode_gru_hidden250_sine_rw10_mode5_extended_6-6_1234_1.pickle
#  create mode 100644 performance/pretrain/pretrain_mode_gru_hidden50_sine_rw10_mode5_extended_6-6_1234_12.pickle
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_100hs/models.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_100hs/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_100hs/train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_100hs_anytime/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_150hs/models.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_150hs/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_150hs/train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_150hs_anytime/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_200hs/models.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_200hs/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_200hs/train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_200hs_anytime/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_250hs/models.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_250hs/test_then_train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_250hs/train.pkl
#  create mode 100644 performance/sine_rw10_mode5_extended_16-16_1234/cpnn_cgru_250hs_anytime/test_then_train.pkl
#  rewrite performance/sine_rw10_mode5_extended_16-16_1432/cpnn_cgru_50hs/models.pkl (85%)
#  rewrite performance/sine_rw10_mode5_extended_16-16_1432/cpnn_cgru_50hs/test_then_train.pkl (97%)
#  rewrite performance/sine_rw10_mode5_extended_16-16_1432/cpnn_cgru_50hs/train.pkl (94%)
#  rewrite performance/sine_rw10_mode5_extended_16-16_1432/cpnn_cgru_50hs_anytime/test_then_train.pkl (98%)
#  rewrite push_to_git.ipynb (95%)
#  create mode 100644 run_test/Hyperparameter selection.ipynb
#  rewrite run_test/cPNN_exiperiments.ipynb (93%)
#  rewrite run_test/plot_final_results.ipynb (79%)
#  rewrite run_test/run_pretrained_model_new thing examine.ipynb (91%)
# Enumerating objects: 70, done.
# Counting objects: 100% (70/70), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (47/47), done.
# Writing objects: 100% (52/52), 43.09 MiB | 8.83 MiB/s, done.
# Total 52 (delta 21), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (21/21), completed with 12 local objects.
# To https://github.com/rezapaki1376/CPNN_PiggyBack
#    571e367..3a05823  main -> main

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (push)
