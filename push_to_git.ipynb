# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# data		     iris-model.pickle	performance	   requirements.txt  Untitled0.ipynb
# datasets	     lab		push_to_git.ipynb  results
# iris-model-full.pth  models		README.md	   run_test

# %%
username = 'rezapaki1376'
email = 'paki.reza@yahoo.com'
repo = 'CPNN_PiggyBack'
token = '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'

# %%
# !git add --all

# %%
# !git config --global user.email "paki.reza@yahoo.com"
# !git config --global user.name "rezapaki1376"

# !git commit -a -m "fixing tenerizer function "
# !git push origin
# Out:
# [main c1386e9] adding best models plot
#  90 files changed, 214 insertions(+), 313 deletions(-)
#  rewrite push_to_git.ipynb (85%)
#  delete mode 100644 results/acc-16_16-1234-1.csv
#  delete mode 100644 results/acc-16_16-1234-2.csv
#  delete mode 100644 results/acc-16_16-1234-3.csv
#  delete mode 100644 results/acc-16_16-1234-4.csv
#  create mode 100644 results/acc-16_16-1234-puretrain.csv
#  delete mode 100644 results/acc-16_16-1432-1.csv
#  delete mode 100644 results/acc-16_16-1432-2.csv
#  delete mode 100644 results/acc-16_16-1432-3.csv
#  delete mode 100644 results/acc-16_16-1432-4.csv
#  create mode 100644 results/acc-16_16-1432-puretrain.csv
#  delete mode 100644 results/acc-16_16-2143-1.csv
#  delete mode 100644 results/acc-16_16-2143-2.csv
#  delete mode 100644 results/acc-16_16-2143-3.csv
#  delete mode 100644 results/acc-16_16-2143-4.csv
#  create mode 100644 results/acc-16_16-2143-puretrain.csv
#  delete mode 100644 results/acc-16_16-2341-1.csv
#  delete mode 100644 results/acc-16_16-2341-2.csv
#  delete mode 100644 results/acc-16_16-2341-3.csv
#  delete mode 100644 results/acc-16_16-2341-4.csv
#  create mode 100644 results/acc-16_16-2341-puretrain.csv
#  rewrite results/acc-CPB-16_16-1234-t1.csv (90%)
#  rewrite results/acc-CPB-16_16-1234-t2.csv (90%)
#  rewrite results/acc-CPB-16_16-1234-t3.csv (90%)
#  rewrite results/acc-CPB-16_16-1234-t4.csv (90%)
#  create mode 100644 results/acc-CPB-16_16-1432-t1.csv
#  rewrite results/acc-CPB-16_16-1432-t2.csv (90%)
#  rewrite results/acc-CPB-16_16-1432-t3.csv (90%)
#  rewrite results/acc-CPB-16_16-1432-t4.csv (89%)
#  rewrite results/acc-CPB-16_16-2143-t1.csv (90%)
#  rewrite results/acc-CPB-16_16-2143-t2.csv (90%)
#  rewrite results/acc-CPB-16_16-2143-t3.csv (90%)
#  rewrite results/acc-CPB-16_16-2143-t4.csv (90%)
#  rewrite results/acc-CPB-16_16-2341-t1.csv (90%)
#  rewrite results/acc-CPB-16_16-2341-t2.csv (90%)
#  rewrite results/acc-CPB-16_16-2341-t3.csv (90%)
#  rewrite results/acc-CPB-16_16-2341-t4.csv (90%)
#  create mode 100644 results/acc-CPB-16_16-frozen-1432-t1.csv
#  delete mode 100644 results/kappa-16_16-1234-1.csv
#  delete mode 100644 results/kappa-16_16-1234-2.csv
#  delete mode 100644 results/kappa-16_16-1234-3.csv
#  delete mode 100644 results/kappa-16_16-1234-4.csv
#  create mode 100644 results/kappa-16_16-1234-puretrain.csv
#  delete mode 100644 results/kappa-16_16-1432-1.csv
#  delete mode 100644 results/kappa-16_16-1432-2.csv
#  delete mode 100644 results/kappa-16_16-1432-3.csv
#  delete mode 100644 results/kappa-16_16-1432-4.csv
#  create mode 100644 results/kappa-16_16-1432-puretrain.csv
#  delete mode 100644 results/kappa-16_16-2143-1.csv
#  delete mode 100644 results/kappa-16_16-2143-2.csv
#  delete mode 100644 results/kappa-16_16-2143-3.csv
#  delete mode 100644 results/kappa-16_16-2143-4.csv
#  create mode 100644 results/kappa-16_16-2143-puretrain.csv
#  delete mode 100644 results/kappa-16_16-2341-1.csv
#  delete mode 100644 results/kappa-16_16-2341-2.csv
#  delete mode 100644 results/kappa-16_16-2341-3.csv
#  delete mode 100644 results/kappa-16_16-2341-4.csv
#  create mode 100644 results/kappa-16_16-2341-puretrain.csv
#  rewrite results/kappa-CPB-16_16-1234-t1.csv (95%)
#  rewrite results/kappa-CPB-16_16-1234-t2.csv (94%)
#  rewrite results/kappa-CPB-16_16-1234-t3.csv (94%)
#  rewrite results/kappa-CPB-16_16-1234-t4.csv (94%)
#  create mode 100644 results/kappa-CPB-16_16-1432-t1.csv
#  rewrite results/kappa-CPB-16_16-1432-t2.csv (94%)
#  rewrite results/kappa-CPB-16_16-1432-t3.csv (94%)
#  rewrite results/kappa-CPB-16_16-1432-t4.csv (94%)
#  rewrite results/kappa-CPB-16_16-2143-t1.csv (94%)
#  rewrite results/kappa-CPB-16_16-2143-t2.csv (94%)
#  rewrite results/kappa-CPB-16_16-2143-t3.csv (94%)
#  rewrite results/kappa-CPB-16_16-2143-t4.csv (94%)
#  rewrite results/kappa-CPB-16_16-2341-t1.csv (94%)
#  rewrite results/kappa-CPB-16_16-2341-t2.csv (94%)
#  rewrite results/kappa-CPB-16_16-2341-t3.csv (94%)
#  rewrite results/kappa-CPB-16_16-2341-t4.csv (94%)
#  create mode 100644 results/kappa-CPB-16_16-frozen-1432-t1.csv
#  rewrite run_test/cPNN_exiperiments.ipynb (96%)
#  create mode 100644 run_test/plot_final_results.ipynb
#  rewrite run_test/run_pretrained_model.ipynb (95%)
# Enumerating objects: 88, done.
# Counting objects: 100% (88/88), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (64/64), done.
# Writing objects: 100% (64/64), 1.49 MiB | 3.45 MiB/s, done.
# Total 64 (delta 26), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (26/26), completed with 14 local objects.
# To https://github.com/rezapaki1376/CPNN_PiggyBack
#    118acd6..c1386e9  main -> main

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (push)
