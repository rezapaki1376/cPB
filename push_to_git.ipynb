# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd drive/My Drive/Thesis/CPNN_PiggyBack
# !ls
# Out:
# /content/drive/My Drive/Thesis/CPNN_PiggyBack
# data		     iris-model.pickle	performance	   requirements.txt  Untitled0.ipynb
# datasets	     lab		push_to_git.ipynb  results
# iris-model-full.pth  models		README.md	   run_test

# %%
username = 'rezapaki1376'
email = 'paki.reza@yahoo.com'
repo = 'CPNN_PiggyBack'
token = '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'

# %%
# !git add --all

# %%
# !git config --global user.email "paki.reza@yahoo.com"
# !git config --global user.name "rezapaki1376"

# !git commit -a -m "first version of piggyback on LSTM implemented"
# !git push origin
# Out:
# [main 9454da7] first version of piggyback on LSTM implemented
#  9 files changed, 6 insertions(+), 4 deletions(-)
#  create mode 100644 performance/pretrain/pretrain_mode_lstm_sine_rw10_mode5_extended_6-6_1234_1.pickle
#  rewrite push_to_git.ipynb (80%)
#  rewrite run_test/cPNN_exiperiments.ipynb (96%)
#  rewrite run_test/run_pretrained_model_new thing examine.ipynb (93%)
# Enumerating objects: 27, done.
# Counting objects: 100% (27/27), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (16/16), done.
# Writing objects: 100% (16/16), 79.52 KiB | 3.31 MiB/s, done.
# Total 16 (delta 10), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (10/10), completed with 10 local objects.
# To https://github.com/rezapaki1376/CPNN_PiggyBack
#    6d79620..9454da7  main -> main

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (fetch)
# origin	https://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@github.com/rezapaki1376/CPNN_PiggyBack (push)
